# %%
import pandas as pd
# data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data', header=None)
data5 =  pd.read_csv('C:/Users/alemu/OneDrive/Desktop/Final/macro5.csv', header=None)
data10 =  pd.read_csv('C:/Users/alemu/OneDrive/Desktop/Final/macro10.csv', header=None)
data15 =  pd.read_csv('C:/Users/alemu/OneDrive/Desktop/Final/macro15.csv', header=None)
data20 =  pd.read_csv('C:/Users/alemu/OneDrive/Desktop/Final/macro20.csv', header=None)
data5.columns = ['Size_Buffer', 'Size_Window', 'ts', 'allocaBuffer',
                'scope', 'addToBuffer', 'tick', 'extractData',
                'evictWindow', 'totem',]
data10.columns = ['Size_Buffer', 'Size_Window', 'ts', 'allocaBuffer',
                'scope', 'addToBuffer', 'tick', 'extractData',
                'evictWindow', 'totem',]
data15.columns = ['Size_Buffer', 'Size_Window', 'ts', 'allocaBuffer',
                'scope', 'addToBuffer', 'tick', 'extractData',
                'evictWindow', 'totem',]
data20.columns = ['Size_Buffer', 'Size_Window', 'ts', 'allocaBuffer',
                'scope', 'addToBuffer', 'tick', 'extractData',
                'evictWindow', 'totem',]

# %%
print('Number of instances 5 = %d' % (data5.shape[0]))
print('Number of attributes 5= %d' % (data5.shape[1]))
print('Number of instances 10= %d' % (data10.shape[0]))
print('Number of attributes 10= %d' % (data10.shape[1]))
print('Number of instances 15= %d' % (data15.shape[0]))
print('Number of attributes 15= %d' % (data15.shape[1]))
print('Number of instances 20= %d' % (data20.shape[0]))
print('Number of attributes 20= %d' % (data20.shape[1]))
# Out:
# Number of instances 5= 4999
# Number of attributes 5= 10
# Number of instances 10= 4999
# Number of attributes 10= 10
# Number of instances 15= 4381
# Number of attributes 15= 10
# Number of instances 20= 4999
# Number of attributes 20= 10

# %%
df5 = pd.DataFrame(data5)
df10 = pd.DataFrame(data10)
df15 = pd.DataFrame(data15)
df20 = pd.DataFrame(data20)

# %%
allocaBuffer5 = df5['allocaBuffer'].mean()
scope5 = df5['scope'].mean()
addToBuffer5 = df5['addToBuffer'].mean()
tick5 = df5['tick'].mean()
extractData5 = df5['extractData'].mean()
evictWindow5 = df5['evictWindow'].mean()
totem5 = df5['totem'].mean()

allocaBuffer10 = df10['allocaBuffer'].mean()
scope10 = df10['scope'].mean()
addToBuffer10 = df10['addToBuffer'].mean()
tick10 = df10['tick'].mean()
extractData10 = df10['extractData'].mean()
evictWindow10 = df10['evictWindow'].mean()
totem10 = df10['totem'].mean()

allocaBuffer15 = df15['allocaBuffer'].mean()
scope15 = df15['scope'].mean()
addToBuffer15 = df15['addToBuffer'].mean()
tick15 = df15['tick'].mean()
extractData15 = df15['extractData'].mean()
evictWindow15 = df15['evictWindow'].mean()
totem15 = df15['totem'].mean()

allocaBuffer20 = df20['allocaBuffer'].mean()
scope20 = df20['scope'].mean()
addToBuffer20 = df20['addToBuffer'].mean()
tick20 = df20['tick'].mean()
extractData20 = df20['extractData'].mean()
evictWindow20 = df20['evictWindow'].mean()
totem20 = df20['totem'].mean()

# %%
print("5:")
print(allocaBuffer5) 
print(scope5)
print(addToBuffer5)
print(tick5)
print(extractData5)
print(evictWindow5)
print(totem5)

print("10:")
print(allocaBuffer10) 
print(scope10)
print(addToBuffer10)
print(tick10)
print(extractData10)
print(evictWindow10)
print(totem10)

print("15:")
print(allocaBuffer15) 
print(scope15)
print(addToBuffer15)
print(tick15)
print(extractData15)
print(evictWindow15)
print(totem15)

print("20:")
print(allocaBuffer20) 
print(scope20)
print(addToBuffer20)
print(tick20)
print(extractData20)
print(evictWindow20)
print(totem20)
# Out:
# 5:
# 0.0
# 0.11782356471294259
# 1.5979195839167835
# 0.0
# 5.29005801160232
# 0.08021604320864173
# 7.082216443288658
# 10:
# 0.0
# 0.20964192838567713
# 2.81496299259852
# 0.0
# 15.14002800560112
# 0.07141428285657131
# 18.245649129825964
# 15:
# 0.0
# 0.09449897283725177
# 4.667655786350148
# 0.0
# 33.40104998858708
# 0.07692307692307693
# 38.26341018032413
# 20:
# 0.00020004000800160032
# 0.16523304660932187
# 6.180036007201441
# 0.0
# 54.50910182036407
# 0.40028005601120226
# 61.33146629325865

# %%
import numpy as np 
import matplotlib.pyplot as plt 

allocaBuffer = [allocaBuffer5,allocaBuffer10,allocaBuffer15,allocaBuffer20]
scope = [scope5,scope10,scope15,scope20] 
addToBuffer = [addToBuffer5,addToBuffer10,addToBuffer15,addToBuffer20] 
tick = [tick5,tick10,tick15,tick20] 
extractData = [extractData5,extractData10,extractData15,extractData20] 
evictWindow = [evictWindow5,evictWindow10,evictWindow15,evictWindow20] 
totem = [totem5,totem10,totem15,totem20] 
y = ['5','10','15','20']

# %%
plt.plot(y,allocaBuffer, marker = "o", color = 'red') 
plt.title("allocaBuffer") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()

# %%
plt.plot(y,scope, marker = "o", color = 'blue') 
plt.title("scope") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()

# %%
plt.plot(y,addToBuffer, marker = "o", color = 'green') 
plt.title("addToBuffer") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()

# %%
plt.plot(y,tick, marker = "o", color = 'yellow') 
plt.title("tick") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()

# %%
plt.plot(y,extractData, marker = "o", color = 'black') 
plt.title("extractData") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()

# %%
plt.plot(y,evictWindow, marker = "o", color = 'purple') 
plt.title("evictWindow") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()

# %%
plt.plot(y,totem, marker = "o", color = 'grey') 
plt.title("totem") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()
