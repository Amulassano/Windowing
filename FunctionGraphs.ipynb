# %%
import pandas as pd
# data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data', header=None)
data100e1 =  pd.read_csv('C:/Users/alemu/OneDrive/Desktop/Final/final100-1.csv', header=None)
data100e2 =  pd.read_csv('C:/Users/alemu/OneDrive/Desktop/Final/final100-2.csv', header=None)
data100e3 =  pd.read_csv('C:/Users/alemu/OneDrive/Desktop/Final/final100-3.csv', header=None)
data100e4 =  pd.read_csv('C:/Users/alemu/OneDrive/Desktop/Final/final100-4.csv', header=None)
data100e1.columns = ['Size_Buffer', 'Size_Window', 'ts', 'allocaBuffer',
                'scope', 'addToBuffer', 'tick', 'extractData',
                'evictWindow', 'totem',]
data100e2.columns = ['Size_Buffer', 'Size_Window', 'ts', 'allocaBuffer',
                'scope', 'addToBuffer', 'tick', 'extractData',
                'evictWindow', 'totem',]
data100e3.columns = ['Size_Buffer', 'Size_Window', 'ts', 'allocaBuffer',
                'scope', 'addToBuffer', 'tick', 'extractData',
                'evictWindow', 'totem',]
data100e4.columns = ['Size_Buffer', 'Size_Window', 'ts', 'allocaBuffer',
                'scope', 'addToBuffer', 'tick', 'extractData',
                'evictWindow', 'totem',]

# %%
data1000e1 =  pd.read_csv('C:/Users/alemu/OneDrive/Desktop/Final/final1000-1.csv', header=None)
data1000e2 =  pd.read_csv('C:/Users/alemu/OneDrive/Desktop/Final/final1000-2.csv', header=None)
data1000e3 =  pd.read_csv('C:/Users/alemu/OneDrive/Desktop/Final/final1000-3.csv', header=None)
data1000e4 =  pd.read_csv('C:/Users/alemu/OneDrive/Desktop/Final/final1000-4.csv', header=None)
data1000e1.columns = ['Size_Buffer', 'Size_Window', 'ts', 'allocaBuffer',
                'scope', 'addToBuffer', 'tick', 'extractData',
                'evictWindow', 'totem',]
data1000e2.columns = ['Size_Buffer', 'Size_Window', 'ts', 'allocaBuffer',
                'scope', 'addToBuffer', 'tick', 'extractData',
                'evictWindow', 'totem',]
data1000e3.columns = ['Size_Buffer', 'Size_Window', 'ts', 'allocaBuffer',
                'scope', 'addToBuffer', 'tick', 'extractData',
                'evictWindow', 'totem',]
data1000e4.columns = ['Size_Buffer', 'Size_Window', 'ts', 'allocaBuffer',
                'scope', 'addToBuffer', 'tick', 'extractData',
                'evictWindow', 'totem',]

# %%
data5000 =  pd.read_csv('C:/Users/alemu/OneDrive/Desktop/Final/final5000-1.csv', header=None)
data10000 =  pd.read_csv('C:/Users/alemu/OneDrive/Desktop/Final/final10000-1.csv', header=None)
data5000.columns = ['Size_Buffer', 'Size_Window', 'ts', 'allocaBuffer',
                'scope', 'addToBuffer', 'tick', 'extractData',
                'evictWindow', 'totem',]
data10000.columns = ['Size_Buffer', 'Size_Window', 'ts', 'allocaBuffer',
                'scope', 'addToBuffer', 'tick', 'extractData',
                'evictWindow', 'totem',]

# %%
df100e1 = pd.DataFrame(data100e1)
df100e2 = pd.DataFrame(data100e2)
df100e3 = pd.DataFrame(data100e3)
df100e4 = pd.DataFrame(data100e4)

# %%
df1000e1 = pd.DataFrame(data1000e1)
df1000e2 = pd.DataFrame(data1000e2)
df1000e3 = pd.DataFrame(data1000e3)
df1000e4 = pd.DataFrame(data1000e4)

# %%
df5000 = pd.DataFrame(data5000)
df10000 = pd.DataFrame(data10000)

# %%
allocaBuffer100e1 = df100e1['allocaBuffer'].mean()
scope100e1 = df100e1['scope'].mean()
addToBuffer100e1 = df100e1['addToBuffer'].mean()
tick100e1 = df100e1['tick'].mean()
extractData100e1 = df100e1['extractData'].mean()
evictWindow100e1 = df100e1['evictWindow'].mean()
totem100e1 = df100e1['totem'].mean()

allocaBuffer100e2 = df100e2['allocaBuffer'].mean()
scope100e2 = df100e2['scope'].mean()
addToBuffer100e2 = df100e2['addToBuffer'].mean()
tick100e2 = df100e2['tick'].mean()
extractData100e2 = df100e2['extractData'].mean()
evictWindow100e2 = df100e2['evictWindow'].mean()
totem100e2 = df100e2['totem'].mean()

allocaBuffer100e3 = df100e3['allocaBuffer'].mean()
scope100e3 = df100e3['scope'].mean()
addToBuffer100e3 = df100e3['addToBuffer'].mean()
tick100e3 = df100e3['tick'].mean()
extractData100e3 = df100e3['extractData'].mean()
evictWindow100e3 = df100e3['evictWindow'].mean()
totem100e3 = df100e3['totem'].mean()

allocaBuffer100e4 = df100e4['allocaBuffer'].mean()
scope100e4 = df100e4['scope'].mean()
addToBuffer100e4 = df100e4['addToBuffer'].mean()
tick100e4 = df100e4['tick'].mean()
extractData100e4 = df100e4['extractData'].mean()
evictWindow100e4 = df100e4['evictWindow'].mean()
totem100e4 = df100e4['totem'].mean()

# %%
allocaBuffer1000e1 = df1000e1['allocaBuffer'].mean()
scope1000e1 = df1000e1['scope'].mean()
addToBuffer1000e1 = df1000e1['addToBuffer'].mean()
tick1000e1 = df1000e1['tick'].mean()
extractData1000e1 = df1000e1['extractData'].mean()
evictWindow1000e1 = df1000e1['evictWindow'].mean()
totem1000e1 = df1000e1['totem'].mean()

allocaBuffer1000e2 = df1000e2['allocaBuffer'].mean()
scope1000e2 = df1000e2['scope'].mean()
addToBuffer1000e2 = df1000e2['addToBuffer'].mean()
tick1000e2 = df1000e2['tick'].mean()
extractData1000e2 = df1000e2['extractData'].mean()
evictWindow1000e2 = df1000e2['evictWindow'].mean()
totem1000e2 = df1000e2['totem'].mean()

allocaBuffer1000e3 = df1000e3['allocaBuffer'].mean()
scope1000e3 = df1000e3['scope'].mean()
addToBuffer1000e3 = df1000e3['addToBuffer'].mean()
tick1000e3 = df1000e3['tick'].mean()
extractData1000e3 = df1000e3['extractData'].mean()
evictWindow1000e3 = df1000e3['evictWindow'].mean()
totem1000e3 = df1000e3['totem'].mean()

allocaBuffer1000e4 = df1000e4['allocaBuffer'].mean()
scope1000e4 = df1000e4['scope'].mean()
addToBuffer1000e4 = df1000e4['addToBuffer'].mean()
tick1000e4 = df1000e4['tick'].mean()
extractData1000e4 = df1000e4['extractData'].mean()
evictWindow1000e4 = df1000e4['evictWindow'].mean()
totem1000e4 = df1000e4['totem'].mean()

# %%
allocaBuffer5000 = df5000['allocaBuffer'].mean()
scope5000 = df5000['scope'].mean()
addToBuffer5000 = df5000['addToBuffer'].mean()
tick5000 = df5000['tick'].mean()
extractData5000 = df5000['extractData'].mean()
evictWindow5000 = df5000['evictWindow'].mean()
totem5000 = df5000['totem'].mean()

allocaBuffer10000 = df10000['allocaBuffer'].mean()
scope10000 = df10000['scope'].mean()
addToBuffer10000 = df10000['addToBuffer'].mean()
tick10000 = df10000['tick'].mean()
extractData10000 = df10000['extractData'].mean()
evictWindow10000 = df10000['evictWindow'].mean()
totem10000 = df10000['totem'].mean()

# %%
allocaBuffer100 = (allocaBuffer100e1+allocaBuffer100e2+allocaBuffer100e3+allocaBuffer100e4)/4
scope100 = (scope100e1+scope100e2+scope100e3+scope100e4)/4
addToBuffer100 = (addToBuffer100e1+addToBuffer100e2+addToBuffer100e3+addToBuffer100e4)/4
tick100 = (tick100e2+tick100e3+tick100e4+tick100e1)/4
extractData100 = (extractData100e1+extractData100e2+extractData100e3+extractData100e4)/4
evictWindow100 = (evictWindow100e1+evictWindow100e2+evictWindow100e3+evictWindow100e4)/4
totem100 = (totem100e1+totem100e2+totem100e3+totem100e4)/4

# %%
allocaBuffer1000 = (allocaBuffer1000e1+allocaBuffer1000e2+allocaBuffer1000e3+allocaBuffer1000e4)/4
scope1000 = (scope1000e1+scope1000e2+scope1000e3+scope1000e4)/4
addToBuffer1000 = (addToBuffer1000e1+addToBuffer1000e2+addToBuffer1000e3+addToBuffer1000e4)/4
tick1000 = (tick1000e2+tick1000e3+tick1000e4+tick1000e1)/4
extractData1000 = (extractData1000e1+extractData1000e2+extractData1000e3+extractData1000e4)/4
evictWindow1000 = (evictWindow1000e1+evictWindow1000e2+evictWindow1000e3+evictWindow1000e4)/4
totem1000 = (totem1000e1+totem1000e2+totem1000e3+totem1000e4)/4

# %%
import numpy as np 
import matplotlib.pyplot as plt 

allocaBuffer = [allocaBuffer100,allocaBuffer1000,allocaBuffer5000,allocaBuffer10000]
scope = [scope100,scope1000,scope5000,scope10000] 
addToBuffer = [addToBuffer100,addToBuffer1000,addToBuffer5000,addToBuffer10000] 
tick = [tick100,tick1000,tick5000,tick10000] 
extractData = [extractData100,extractData1000,extractData5000,extractData10000] 
evictWindow = [evictWindow100,evictWindow1000,evictWindow5000,evictWindow10000] 
totem = [totem100,totem1000,totem5000,totem10000] 
y = [int(100),int(1000),int(5000),int(10000)]

# %%
plt.plot(y,allocaBuffer, marker = "o", color = 'red') 
plt.title("allocaBuffer") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()

# %%
plt.plot(y,scope, marker = "o", color = 'blue') 
plt.title("scope") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()

# %%
plt.plot(y,addToBuffer, marker = "o", color = 'green') 
plt.title("addToBuffer") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()

# %%
plt.plot(y,tick, marker = "o", color = 'yellow') 
plt.title("tick") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()

# %%
plt.plot(y,extractData, marker = "o", color = 'black') 
plt.title("extractData") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()

# %%
plt.plot(y,evictWindow, marker = "o", color = 'purple') 
plt.title("evictWindow") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()

# %%
plt.plot(y,totem, marker = "o", color = 'grey') 
plt.title("totem") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()
