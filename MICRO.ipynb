# %%
import pandas as pd
# data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data', header=None)
data5 =  pd.read_csv('C:/Users/alemu/OneDrive/Desktop/Final/micro500.csv', header=None)
data10 =  pd.read_csv('C:/Users/alemu/OneDrive/Desktop/Final/micro1000.csv', header=None)
data15 =  pd.read_csv('C:/Users/alemu/OneDrive/Desktop/Final/micro2000.csv', header=None)
data20 =  pd.read_csv('C:/Users/alemu/OneDrive/Desktop/Final/micro5000.csv', header=None)
data5.columns = ['Size_Buffer', 'Size_Window', 'ts', 'allocaBuffer',
                'scope', 'addToBuffer', 'tick', 'extractData',
                'evictWindow', 'totem',]
data10.columns = ['Size_Buffer', 'Size_Window', 'ts', 'allocaBuffer',
                'scope', 'addToBuffer', 'tick', 'extractData',
                'evictWindow', 'totem',]
data15.columns = ['Size_Buffer', 'Size_Window', 'ts', 'allocaBuffer',
                'scope', 'addToBuffer', 'tick', 'extractData',
                'evictWindow', 'totem',]
data20.columns = ['Size_Buffer', 'Size_Window', 'ts', 'allocaBuffer',
                'scope', 'addToBuffer', 'tick', 'extractData',
                'evictWindow', 'totem',]

# %%
print('Number of instances 500= %d' % (data5.shape[0]))
print('Number of attributes 500= %d' % (data5.shape[1]))
print('Number of instances 1000= %d' % (data10.shape[0]))
print('Number of attributes 1000= %d' % (data10.shape[1]))
print('Number of instances 2000= %d' % (data15.shape[0]))
print('Number of attributes 2000= %d' % (data15.shape[1]))
print('Number of instances 5000= %d' % (data20.shape[0]))
print('Number of attributes 5000= %d' % (data20.shape[1]))
# Out:
# Number of instances 500= 49999
# Number of attributes 500= 10
# Number of instances 1000= 49999
# Number of attributes 1000= 10
# Number of instances 2000= 49999
# Number of attributes 2000= 10
# Number of instances 5000= 49999
# Number of attributes 5000= 10

# %%
df5 = pd.DataFrame(data5)
df10 = pd.DataFrame(data10)
df15 = pd.DataFrame(data15)
df20 = pd.DataFrame(data20)

# %%
allocaBuffer5 = df5['allocaBuffer'].mean()
scope5 = df5['scope'].mean()
addToBuffer5 = df5['addToBuffer'].mean()
tick5 = df5['tick'].mean()
extractData5 = df5['extractData'].mean()
evictWindow5 = df5['evictWindow'].mean()
totem5 = df5['totem'].mean()

allocaBuffer10 = df10['allocaBuffer'].mean()
scope10 = df10['scope'].mean()
addToBuffer10 = df10['addToBuffer'].mean()
tick10 = df10['tick'].mean()
extractData10 = df10['extractData'].mean()
evictWindow10 = df10['evictWindow'].mean()
totem10 = df10['totem'].mean()

allocaBuffer15 = df15['allocaBuffer'].mean()
scope15 = df15['scope'].mean()
addToBuffer15 = df15['addToBuffer'].mean()
tick15 = df15['tick'].mean()
extractData15 = df15['extractData'].mean()
evictWindow15 = df15['evictWindow'].mean()
totem15 = df15['totem'].mean()

allocaBuffer20 = df20['allocaBuffer'].mean()
scope20 = df20['scope'].mean()
addToBuffer20 = df20['addToBuffer'].mean()
tick20 = df20['tick'].mean()
extractData20 = df20['extractData'].mean()
evictWindow20 = df20['evictWindow'].mean()
totem20 = df20['totem'].mean()

# %%
print("500:")
print(allocaBuffer5) 
print(scope5)
print(addToBuffer5)
print(tick5)
print(extractData5)
print(evictWindow5)
print(totem5)

print("1000:")
print(allocaBuffer10) 
print(scope10)
print(addToBuffer10)
print(tick10)
print(extractData10)
print(evictWindow10)
print(totem10)

print("2000:")
print(allocaBuffer15) 
print(scope15)
print(addToBuffer15)
print(tick15)
print(extractData15)
print(evictWindow15)
print(totem15)

print("5000:")
print(allocaBuffer20) 
print(scope20)
print(addToBuffer20)
print(tick20)
print(extractData20)
print(evictWindow20)
print(totem20)
# Out:
# 500:
# 0.00012000240004800096
# 0.0988219764395288
# 0.09120182403648074
# 0.00024000480009600192
# 1.4384287685753716
# 0.0759015180303606
# 1.7046740934818696
# 1000:
# 6.000120002400048e-05
# 0.19766395327906558
# 0.2716254325086502
# 0.0001600032000640013
# 6.28282565651313
# 0.09428188563771275
# 6.849756995139903
# 2000:
# 0.0002000040000800016
# 0.5797315946318926
# 0.49502990059801194
# 0.00018000360007200145
# 24.282345646912937
# 0.10406208124162483
# 25.513730274605493
# 5000:
# 2.000040000800016e-05
# 0.19416388327766557
# 1.725434508690174
# 0.0005200104002080041
# 148.77279545590912
# 0.0998819976399528
# 150.7965159303186

# %%
import numpy as np 
import matplotlib.pyplot as plt 

allocaBuffer = [allocaBuffer5,allocaBuffer10,allocaBuffer15,allocaBuffer20]
scope = [scope5,scope10,scope15,scope20] 
addToBuffer = [addToBuffer5,addToBuffer10,addToBuffer15,addToBuffer20] 
tick = [tick5,tick10,tick15,tick20] 
extractData = [extractData5,extractData10,extractData15,extractData20] 
evictWindow = [evictWindow5,evictWindow10,evictWindow15,evictWindow20] 
totem = [totem5,totem10,totem15,totem20] 
y = ['500','1000','2000','5000']

# %%
plt.plot(y,allocaBuffer, marker = "o", color = 'red') 
plt.title("allocaBuffer") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()

# %%
plt.plot(y,scope, marker = "o", color = 'blue') 
plt.title("scope") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()

# %%
plt.plot(y,addToBuffer, marker = "o", color = 'green') 
plt.title("addToBuffer") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()

# %%
plt.plot(y,tick, marker = "o", color = 'yellow') 
plt.title("tick") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()

# %%
plt.plot(y,extractData, marker = "o", color = 'black') 
plt.title("extractData") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()

# %%
plt.plot(y,evictWindow, marker = "o", color = 'purple') 
plt.title("evictWindow") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()

# %%
plt.plot(y,totem, marker = "o", color = 'grey') 
plt.title("totem") 
plt.grid() 
plt.xlabel("width") 
plt.ylabel("ms") 
plt.show()
